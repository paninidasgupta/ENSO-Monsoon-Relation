# %%
from matplotlib import pyplot as plt
import numpy as np
import netCDF4 as nc
import xarray as xr
import datetime as dt
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from pandas import DataFrame
from scipy import stats,signal

# %% [markdown]
# # Nino

# %%
# data1 = "/home/cccr/roxy/athira/ninosst.txt"
# f = open("ninosst.txt", "r")

matrix1=np.loadtxt("/home/cccr/roxy/athira/biplot_monsoon/ninosst.txt")
year=matrix1[:,0]
data=matrix1[:,1:]
ind1= np.where((year==1901))[0][0]
ind2= np.where((year==2018))[0][0]
year1=matrix1[ind1:ind2+1,0]
data1=matrix1[ind1:ind2+1,1:]
data1_df=pd.DataFrame(data1,index=year1)
aa=data1_df.iloc[:,[5,6,7,8]].values.ravel()
a=pd.Series(aa,pd.date_range('1/06/1901', periods=len(aa), freq='T'))
bb=a.resample('4T').mean().values
index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')
b=pd.Series(bb,index = index1)

nino_df=pd.DataFrame(b, index=index1, columns=[' N3.4 '])
d= signal.detrend(nino_df.values.squeeze())
nino_df_detrend=pd.DataFrame(d, index=index1, columns=[' Nino 3.4 '])
# nino_df_detrend
# Out:
# /tmp/ipykernel_144490/2040571258.py:15: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')

# %% [markdown]
# ## IPO

# %%
matrix1=np.loadtxt("/home/cccr/roxy/athira/enso_paper/tpi.txt")
year=matrix1[:,0]
data=matrix1[:,1:]
ind1= np.where((year==1901))[0][0]
ind2= np.where((year==2018))[0][0]
year1=matrix1[ind1:ind2+1,0]
data1=matrix1[ind1:ind2+1,1:]
data1_df=pd.DataFrame(data1,index=year1)
aa=data1_df.iloc[:,[5,6,7,8]].values.ravel()
a=pd.Series(aa,pd.date_range('1/06/1901', periods=len(aa), freq='T'))
bb=a.resample('4T').mean().values
index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')
b=pd.Series(bb,index = index1)

tpi_df=pd.DataFrame(b, index=index1, columns=['tpi '])
d= signal.detrend(tpi_df.values.squeeze())
tpi_df_detrend=pd.DataFrame(d, index=index1, columns=[' IPO '])
# nino_df_detrend
# Out:
# /tmp/ipykernel_144490/442403935.py:12: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')

# %% [markdown]
# # AMO

# %%
# data1 = "/home/cccr/roxy/athira/biplot_monsoon/amo.txt"
matrix1 = np.loadtxt("/home/cccr/roxy/athira/biplot_monsoon/amo.txt")

year=matrix1[:,0]
data=matrix1[:,1:]
ind1= np.where((year==1901))[0][0]
ind2= np.where((year==2018))[0][0]
year1=matrix1[ind1:ind2+1,0]
data1=matrix1[ind1:ind2+1,1:]
data1_df=pd.DataFrame(data1,index=year1)
aa=data1_df.iloc[:,[5,6,7,8]].values.ravel()
a=pd.Series(aa,pd.date_range('1/06/1901', periods=len(aa), freq='T'))
bb=a.resample('4T').mean().values
index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')
b=pd.Series(bb,index = index1)


amo_df=pd.DataFrame(b, index=index1, columns=['AMO'])
d= signal.detrend(amo_df.values.squeeze())
amo_df_detrend=pd.DataFrame(d, index=index1, columns=[' AMO '])
# Out:
# /tmp/ipykernel_144490/3502200661.py:14: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')

# %% [markdown]
# # PDO

# %%
# data2 = "/home/cccr/roxy/athira/pdo.txt"
# f = open("pdo.txt", "r")


matrix2 = np.loadtxt("/home/cccr/roxy/athira/biplot_monsoon/pdo.txt")



year=matrix2[:,0]
data=matrix2[:,1:]
ind1= np.where((year==1901))[0][0]
ind2= np.where((year==2018))[0][0]
year1=matrix2[ind1:ind2+1,0]
data1=matrix2[ind1:ind2+1,1:]
data1_df=pd.DataFrame(data1,index=year1)
aa=data1_df.iloc[:,[5,6,7,8]].values.ravel()
a=pd.Series(aa,pd.date_range('1/06/1901', periods=len(aa), freq='T'))
bb=a.resample('4T').mean().values
index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')
b=pd.Series(bb,index = index1)

pdo_df=pd.DataFrame(b, index=index1, columns=['PDO'])
d= signal.detrend(pdo_df.values.squeeze())
pdo_df_detrend=pd.DataFrame(d, index=index1, columns=[' PDO '])
# Out:
# /tmp/ipykernel_144490/1322303313.py:19: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')

# %% [markdown]
# # NAO

# %%
# data3 = "Desktop/DATA/nao.txt"
# f = open("pdo.txt", "r")


matrix3 = np.loadtxt("/home/cccr/roxy/athira/biplot_monsoon/nao.txt")

year=matrix3[:,0]
data=matrix3[:,1:]
ind1= np.where((year==1901))[0][0]
ind2= np.where((year==2018))[0][0]
year1=matrix3[ind1:ind2+1,0]
data1=matrix3[ind1:ind2+1,1:]
data1_df=pd.DataFrame(data1,index=year1)
aa=data1_df.iloc[:,[5,6,7,8]].values.ravel()
a=pd.Series(aa,pd.date_range('1/06/1901', periods=len(aa), freq='T'))
bb=a.resample('4T').mean().values
index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')
b=pd.Series(bb,index = index1)


nao_df=pd.DataFrame(b, index=index1, columns=['NAO'])
d= signal.detrend(nao_df.values.squeeze())
nao_df_detrend=pd.DataFrame(d, index=index1, columns=[' NAO '])
# nao_df
# Out:
# /tmp/ipykernel_144490/3757835311.py:17: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')

# %% [markdown]
# ## IOB

# %%
d = xr.open_dataset("extra_analysis/pcs_iob_yearmean_detrend.nc")
pcs_iob_df = pd.DataFrame(d.sel(time=slice('1901','2019')).pcs[:-1].values, index = index1, columns=['IOB','IPC2','pc3'])
pcs_iob_df=pcs_iob_df.drop(['IPC2','pc3'], axis=1)
pcs_iob_df
# Out:
#                  IOB
# 1901-07-01  0.243797
# 1902-07-01 -0.082112
# 1903-07-01 -0.411841
# 1904-07-01  0.946932
# 1905-07-01  0.131899
# ...              ...
# 2014-07-01 -1.293244
# 2015-07-01 -1.594888
# 2016-07-01 -2.135055
# 2017-07-01 -1.716930
# 2018-07-01 -0.227651
#
# [118 rows x 1 columns]

# %% [markdown]
# # PC1 & PC2

# %%
# !cdo detrend /home/cccr/roxy/athira/pc.yearmean.nc /home/cccr/roxy/athira/pc.yearmean.detrend.nc
# Out:
# Warning (cdfScanVarAttr): NetCDF: Variable not found - time_bnds
# cdo    detrend: Processed 1 variable over 119 timesteps [0.03s 173MB].

# %%
data5 = xr.open_dataset("/home/cccr/roxy/athira/pc.yearmean.detrend.nc")
pcs=data5.pcs.values
pcs=pcs[:-1]
# time=data5.time.values
pcs_df = pd.DataFrame(pcs, index = index1, columns=['IPC1','IPC2','pc3'])
pcs_df=pcs_df.drop(['pc3'], axis=1)

# %% [markdown]
# # South_box

# %% [raw]
# !cdo detrend /home/cccr/roxy/athira/southbox_imd_V2.nc /home/cccr/roxy/athira/biplot_detrended/southbox_imd_V2.detrend.nc

# %% [raw]
# data6 = xr.open_dataset("/home/cccr/roxy/athira/biplot_detrended/southbox_imd_V2.detrend.nc")
# rf_s=data6.rf.values
# time_s=data6.time.values
# south_df = pd.DataFrame(rf_s, index = index1, columns=['S-box'])
# # south_df

# %% [markdown]
# # Central_box

# %% [raw]
# !cdo detrend /home/cccr/roxy/athira/centralbox_imd_V2.nc /home/cccr/roxy/athira/biplot_detrended/centralbox_imd_V2.detrend.nc

# %% [raw]
# data7 = xr.open_dataset("/home/cccr/roxy/athira/biplot_detrended/centralbox_imd_V2.detrend.nc")
# rf_c=data7.rf.values
# time_c=data7.time.values
# central_df = pd.DataFrame(rf_c, index = index1, columns=['C-box'])
# # central_df

# %% [markdown]
# # North_box

# %% [raw]
# !cdo detrend /home/cccr/roxy/athira/northbox_imd_V2.nc /home/cccr/roxy/athira/biplot_detrended/northbox_imd_V2.detrend.nc

# %% [raw]
# data8 = xr.open_dataset("/home/cccr/roxy/athira/biplot_detrended/northbox_imd_V2.detrend.nc")
# rf_n=data8.rf.values
# time_n=data8.time.values
# north_df = pd.DataFrame(rf_n, index = index1, columns=['N-box'])
# # north_df

# %% [markdown]
# # ANI

# %%
ds = xr.open_dataset('/home/cccr/roxy/athira/biplot_monsoon/pc.jjas.atlantic.nino.nc')
ds1=ds.sel(time=slice('1901','2018'))
ds1
pcs=ds1.pcs.values
# # time=data5.time.values
ani_df = pd.DataFrame(pcs, index = index1, columns=['ANIPC1','ANIPC2','anipc3'])
ani_df=ani_df.drop(['ANIPC2','anipc3'], axis=1)
d= signal.detrend(ani_df.values.squeeze())
ani_df_detrend=pd.DataFrame(d, index=index1, columns=[' ANIPC1 '])
ani_df_detrend.std()
# Out:
#  ANIPC1     1.007026
# dtype: float32

# %% [markdown]
# # DMI

# %%
data9 = xr.open_dataset('/home/cccr/roxy/athira/biplot_monsoon/ihadisst1_dmi_mod.jjas.yearmean.1901_2018.nc',decode_times=False)
index2 = pd.date_range(start=pd.datetime(1901,7,1),periods=len(data9['diff']),freq='AS-JUL')
dmi_df = pd.DataFrame(data9['diff'], index = index2, columns=['DMI'])
# dmi_df
d= signal.detrend(dmi_df.values.squeeze())
dmi_df_detrend=pd.DataFrame(d, index=index1, columns=[' DMI '])
# Out:
# /tmp/ipykernel_144490/198518526.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   index2 = pd.date_range(start=pd.datetime(1901,7,1),periods=len(data9['diff']),freq='AS-JUL')

# %% [markdown]
# # QBO_1901-2018

# %%
# data4 = "Desktop/DATA/qbo.txt"
# f = open("pdo.txt", "r")


matrix4 = np.loadtxt("/home/cccr/roxy/athira/biplot_monsoon/qbo.txt")



year=matrix4[:,0]
data=matrix4[:,1:]
ind1= np.where((year==1901))[0][0]
ind2= np.where((year==2018))[0][0]
year1=matrix4[ind1:ind2+1,0]
data1=matrix4[ind1:ind2+1,1:]
data1_df=pd.DataFrame(data1,index=year1)
aa=data1_df.iloc[:,[5,6,7,8]].values.ravel()
a=pd.Series(aa,pd.date_range('1/06/1901', periods=len(aa), freq='T'))
bb=a.resample('4T').mean().values
index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')
b=pd.Series(bb,index = index1)


qbo_df=pd.DataFrame(b, index=index1, columns=[' QBO '])
qbo_df_2=qbo_df.loc['1948':'2018']

std=qbo_df_2[' QBO '].std()
# Out:
# /tmp/ipykernel_43696/2918565425.py:19: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')

# %% [markdown]
# # QBO_1948-2018

# %%
data10 = xr.open_dataset('/home/cccr/roxy/athira/biplot_monsoon/iqbo_mode.jjas.yearmean.1901_2018.nc',decode_times=False )
index3 = pd.date_range(start=pd.datetime(1901,7,1),periods=len(data10['QBO50']),freq='AS-JUL')
qbo_new_df = pd.DataFrame(data10['QBO50'], index = index3, columns=[' QBO '])
qbo_new_df
# data10
qbo_new_df1=qbo_new_df.loc['1901':'1947']
# Out:
# /tmp/ipykernel_43696/2575082096.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   index3 = pd.date_range(start=pd.datetime(1901,7,1),periods=len(data10['QBO50']),freq='AS-JUL')

# %%
# qbo_modified=pd.concat([qbo_new_df1,qbo_df_2], axis=0)
qbo_modified=pd.concat([qbo_new_df1/qbo_new_df1.std(),qbo_df_2/qbo_df_2.std()], axis=0)


d= signal.detrend(qbo_modified.values.squeeze())
qbo_df_detrend=pd.DataFrame(d, index=index1, columns=[' QBO '])

# %%
# !cdo settaxis,1870-01-01,00:00:00,1months ihadisst1_dmi.nc ihadisst1_dmi_mod.nc
# !cdo selmon,6/9 ihadisst1_dmi_mod.nc ihadisst1_dmi_mod.jjas.nc
# !cdo yearmean ihadisst1_dmi_mod.jjas.nc ihadisst1_dmi_mod.jjas.yearmean.nc
# !cdo selyear,1901/2018 ihadisst1_dmi_mod.jjas.yearmean.nc ihadisst1_dmi_mod.jjas.yearmean.1901_2018.nc 
# !rm ihadisst1_dmi_mod*.nc
# !cdo sinfo iqbo_50.nc
# !cdo settaxis,1501-01-01,00:00:00,1months iqbo_50.nc iqbo_mode.nc
# !cdo selmon,6/9 iqbo_mode.nc iqbo_mode.nc.jjas.nc
# !cdo yearmean iqbo_mode.nc.jjas.nc iqbo_mode.nc.jjas.yearmean.nc
# !cdo selyear,1901/2018 iqbo_mode.nc.jjas.yearmean.nc iqbo_mode.nc.jjas.yearmean.1901_2018.nc

# %% [markdown]
# ## Depressions

# %%
data = pd.read_csv('/home/cccr/roxy/athira/depression/depression_frequency.txt', comment='#', header=None, delim_whitespace=True)
data.columns=['year','JF','MAM','JJAS','OND','ANNUAL']
data.set_index('year',inplace=True)
dpfreq=data['JJAS'].loc['1901':'2018'].values.squeeze()
dpfreq = (dpfreq-np.mean(dpfreq))/np.std(dpfreq)
dpfreq_detrend=signal.detrend(dpfreq)
# len(index1)
dpfreq_df_detrend=pd.DataFrame(dpfreq_detrend, index=index1, columns=['MDF'])

# %% [markdown]
# ## MT

# %%
# %store -r vor_anom_850_df_detrend
# %store -r pmsl_df_detrend 
################stored variable source: /athira/enso_paper/extra_analysis/figure1_analysis_part2-pmsl.ipynb############################
# Out:
# no stored variable or alias pmsl_df_detrend

# %%
# %store -r hgt_df_detrend

# %%
pmsl_df_detrend.columns=['MT']
# vor_anom_850_df_detrend
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 pmsl_df_detrend.columns=['MT']
#
# NameError: name 'pmsl_df_detrend' is not defined

# %%
pmsl_df_detrend.plot()

# %% [markdown]
# ## Biplot

# %%
import seaborn as sns

# %%
# df_1901_1940 = pd.concat([1*nino_df_detrend.loc['1901':'1940'],pdo_df_detrend.loc['1901':'1940'],nao_df_detrend.loc['1901':'1940'],qbo_df_detrend.loc['1901':'1940'],amo_df_detrend.loc['1901':'1940'],pcs_df.loc['1901':'1940'],ani_df_detrend.loc['1901':'1940'],dmi_df_detrend.loc['1901':'1940']], axis=1)
# df_1941_1980 =pd.concat([1*nino_df_detrend.loc['1941':'1980'],pdo_df_detrend.loc['1941':'1980'],nao_df_detrend.loc['1941':'1980'],qbo_df_detrend.loc['1941':'1980'],amo_df_detrend.loc['1941':'1980'],pcs_df.loc['1941':'1980'],ani_df_detrend.loc['1941':'1980'],dmi_df_detrend.loc['1941':'1980']], axis=1)
# df_1981_2018 =pd.concat([1*nino_df_detrend.loc['1981':'2018'],pdo_df_detrend.loc['1981':'2018'],nao_df_detrend.loc['1981':'2018'],qbo_df_detrend.loc['1981':'2018'],amo_df_detrend.loc['1981':'2018'],pcs_df.loc['1981':'2018'],ani_df_detrend.loc['1981':'2018'],dmi_df_detrend.loc['1981':'2018']], axis=1)
df = pd.concat([pcs_df,nino_df_detrend,dpfreq_df_detrend,hgt_df_detrend,pcs_iob_df,dmi_df_detrend,tpi_df_detrend,pdo_df_detrend,nao_df_detrend,qbo_df_detrend], axis=1)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Biplot

# %%
def biplot(X,header,target,ax,scale = True,labels=None):
    import numpy as np
    from sklearn.decomposition import PCA
    from sklearn.preprocessing import StandardScaler
    import matplotlib.pyplot as plt

    plt.rcParams.update({'font.size': 20, 'font.family': 'serif'})

    if scale:
        scaler = StandardScaler()
        scaler.fit(X)
        X = scaler.transform(X) 

    pca = PCA()
    x_new = pca.fit_transform(X)  
    score = x_new[:,0:2]
    coeff = np.transpose(pca.components_[0:2, :])  
    print(pca.explained_variance_ratio_)
    xs = score[:,0]
    ys = score[:,1]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())

#     scatter = plt.scatter(xs * scalex,ys * scaley, c = target)
#     ll = np.unique(target)
#     handles = [plt.Line2D([],[],marker="o", ls="", 
#                       color=scatter.cmap(scatter.norm(yi))) for yi in ll]
#     plt.legend(handles, ll)

    for i,val in enumerate(header):
        ax.annotate("", xy=(coeff[i,0], coeff[i,1]), xytext=(0, 0),color = 'k',alpha = 0.5,arrowprops=dict(arrowstyle="->"))
        if labels is None:
            ax.text(coeff[i,0]* 1.18, coeff[i,1] * 1.18, val, color = 'k', ha = 'center', va = 'center')
        else:
            ax.text(coeff[i,0]* 1.18, coeff[i,1] * 1.18, labels[i], color = 'k', ha = 'center', va = 'center')

    ax.set_xlim(-1.2,1.2)
    ax.set_ylim(-1.2,1.2)
    ax.set_xlabel(" PC{}".format(1)+" ("+str(np.around(pca.explained_variance_ratio_[0]*100,2))+"%)",fontsize=20)
    ax.set_ylabel(" PC{}".format(2)+" ("+str(np.around(pca.explained_variance_ratio_[1]*100,2))+"%)",fontsize=20)
    ax.grid()
    ax.tick_params(axis='both', which='major', labelsize=20)

    circle1 = plt.Circle((0, 0), 1.0, color='k',edgecolor='k',alpha=0.1)
    ax.add_artist(circle1)

# %%
# df = pd.concat([pcs_df,nino_df_detrend,dpfreq_df_detrend,pmsl_df_detrend,-1*pcs_iob_df,dmi_df_detrend,pdo_df_detrend,nao_df_detrend,qbo_df_detrend], axis=1)
# plt.rcParams['font.size']=20
df = pd.concat([pcs_df,nino_df_detrend,dpfreq_df_detrend,vor_anom_850_df_detrend,-1*pcs_iob_df,dmi_df_detrend,tpi_df_detrend,pdo_df_detrend,nao_df_detrend,qbo_df_detrend], axis=1)
df.rename(columns={'vor_anom_850': 'MT'}, inplace=True)

df1 =df.dropna()
plt.rcParams['font.size']=15

fig= plt.figure(figsize=(23,10))
ax1 = fig.add_subplot(1,2,1)
# sns.heatmap(df.corr(),annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm',ax=ax1,fmt=".2f")
# mask
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
# adjust mask and df
# mask = mask[1:, :-1]
corr = df.corr()#.iloc[1:,:-1].copy()
# color map
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
# plot heatmap
m=sns.heatmap(corr, annot=True, fmt=".2f", 
           linewidths=6, cmap=cmap, vmin=-1, vmax=1, 
           cbar_kws={"shrink": .8}, square=True,mask=mask)
m.colorbar()
# ticks
yticks = [i.upper() for i in corr.index]
xticks = [i.upper() for i in corr.columns]
plt.yticks(plt.yticks()[0], labels=yticks, rotation=0,fontsize=20)
plt.xticks(plt.xticks()[0], labels=xticks,fontsize=20)
# title
title = 'CORRELATION MATRIX \n(1901-2018)'
plt.title(title,fontsize=18)
ax1.text(0,-1.4,'a',fontsize=30,weight="bold")

ax2 = fig.add_subplot(1,2,2)
plt.rcParams['font.size']=25
biplot(df1,df1.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax2)
ax2.set_title('PCA-Biplot \n(1901-2018)', fontsize=20)
ax2.text(-1.2,1.3,'b',fontsize=30,weight="bold")

# ax2= fig.add_subplot(2,2,2)
# biplot(df_1901_1940,df_1901_1940.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax2)
# ax2.set_title('b) 1901-1940', fontsize=20)
# ax3= fig.add_subplot(2,2,3)
# biplot(df_1941_1980,df_1941_1980.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax3)
# ax3.set_title('c) 1941-1980', fontsize=20)
# ax4= fig.add_subplot(2,2,4)
# biplot(df_1981_2018,df_1981_2018.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax4)
# ax4.set_title('d) 1981-2018', fontsize=20)
# plt.savefig("/home/cccr/roxy/athira/enso_paper/figure5_biplot_detrend1.png", bbox_inches='tight', pad_inches=0.5, dpi=300)
plt.savefig("/home/cccr/roxy/athira/enso_paper/figure5_biplot_detrend1.pdf", bbox_inches='tight', pad_inches=0.5)
# Out:
# /tmp/ipykernel_43696/4274635180.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[44], line 23
#      19 # plot heatmap
#      20 sns.heatmap(corr, annot=True, fmt=".2f",
#      21            linewidths=6, cmap=cmap, vmin=-1, vmax=1,
#      22            cbar_kws={"shrink": .8}, square=True,mask=mask)
# ---> 23 cbar = plt.colorbar()
#      24 for t in cbar.ax.get_yticklabels():
#      25      t.set_fontsize(20)
#
# ...

# %%
# df = pd.concat([pcs_df,nino_df_detrend,dpfreq_df_detrend,pmsl_df_detrend,-1*pcs_iob_df,dmi_df_detrend,pdo_df_detrend,nao_df_detrend,qbo_df_detrend], axis=1)
plt.rcParams['font.size']=20
df = pd.concat([pcs_df,nino_df_detrend,dpfreq_df_detrend,vor_anom_850_df_detrend,-1*pcs_iob_df,dmi_df_detrend,tpi_df_detrend,pdo_df_detrend,nao_df_detrend,qbo_df_detrend], axis=1)
df.rename(columns={'vor_anom_850': 'MT'}, inplace=True)

df1 =df.dropna()
plt.rcParams['font.size']=14

fig= plt.figure(figsize=(22,10))
ax1 = fig.add_subplot(1,2,1)
# sns.heatmap(df.corr(),annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm',ax=ax1,fmt=".2f")
# mask
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
# adjust mask and df
# mask = mask[1:, :-1]
corr = df.corr()#.iloc[1:,:-1].copy()
# color map
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
# plot heatmap
sns.heatmap(corr, annot=True, fmt=".2f", 
           linewidths=5, cmap=cmap, vmin=-1, vmax=1, 
           cbar_kws={"shrink": .8}, square=True,mask=mask)
# ticks
yticks = [i.upper() for i in corr.index]
xticks = [i.upper() for i in corr.columns]
plt.yticks(plt.yticks()[0], labels=yticks, rotation=0)
plt.xticks(plt.xticks()[0], labels=xticks)
# title
title = 'CORRELATION MATRIX \n(1901-2018)'
plt.title(title,fontsize=18)
ax1.text(0,-1.4,'a',fontsize=30,weight="bold")

ax2 = fig.add_subplot(1,2,2)
biplot(df1,df1.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax2)
ax2.set_title('PCA-Biplot \n(1901-2018)', fontsize=20)
ax2.text(-1.2,1.3,'b',fontsize=30,weight="bold")

# ax2= fig.add_subplot(2,2,2)
# biplot(df_1901_1940,df_1901_1940.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax2)
# ax2.set_title('b) 1901-1940', fontsize=20)
# ax3= fig.add_subplot(2,2,3)
# biplot(df_1941_1980,df_1941_1980.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax3)
# ax3.set_title('c) 1941-1980', fontsize=20)
# ax4= fig.add_subplot(2,2,4)
# biplot(df_1981_2018,df_1981_2018.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax4)
# ax4.set_title('d) 1981-2018', fontsize=20)
plt.savefig("/home/cccr/roxy/athira/enso_paper/figure5_biplot_detrend1.png", bbox_inches='tight', pad_inches=0.5, dpi=300)
# Out:
# /tmp/ipykernel_105417/1664800804.py:12: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
# [0.21216823 0.19947135 0.11030998 0.09666798 0.08429655 0.08060544
#  0.06812394 0.06441101 0.03282194 0.02795045 0.02317314]
# /tmp/ipykernel_105417/183440395.py:42: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle1 = plt.Circle((0, 0), 1.0, color='k',edgecolor='k',alpha=0.1)

# %%
# Out:
#                 IPC1      IPC2   Nino 3.4        MDF  vor_anom_850       IOB  \
# 1901-07-01  1.160716 -0.342881   -0.153897 -1.833826 -4.032910e-07 -0.243797
# 1902-07-01  0.852136 -0.860975    1.369791  0.170193 -1.967985e-07  0.082112
# 1903-07-01 -0.607023 -1.983223   -0.126520 -0.817955 -9.823195e-07  0.411841
# 1904-07-01  1.202513  0.539508    0.512169 -0.310020  1.016349e-06 -0.946932
# 1905-07-01  1.626502 -0.828349    1.118357 -0.799473 -2.327410e-07 -0.131899
# ...              ...       ...         ...       ...           ...       ...
# 2014-07-01  0.996507 -0.275095    0.287914 -1.288282  4.131919e-07  1.293244
# 2015-07-01  0.690085 -0.669869    1.686603 -0.780346 -6.077043e-08  1.594888
# 2016-07-01 -0.345643  0.351865   -0.277209 -0.771105           NaN  2.135055
# 2017-07-01  0.265642 -1.012714   -0.071020 -0.263170           NaN  1.716930
# 2018-07-01  0.587311  0.615343    0.187668 -0.253929           NaN  0.227651
#
# ...

# %%
df = pd.concat([pcs_df,nino_df_detrend,-1*pcs_iob_df,dmi_df_detrend,tpi_df_detrend,pdo_df_detrend,nao_df_detrend,qbo_df_detrend], axis=1)
df1 =df.dropna()
plt.rcParams['font.size']=13

fig= plt.figure(figsize=(22,10))
ax1 = fig.add_subplot(1,2,1)
# sns.heatmap(df.corr(),annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm',ax=ax1,fmt=".2f")
# mask
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
# adjust mask and df
mask = mask[1:, :-1]
corr = df.corr()#.iloc[1:,:-1].copy()
# color map
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
# plot heatmap
sns.heatmap(corr, annot=True, fmt=".2f", 
           linewidths=5, cmap=cmap, vmin=-1, vmax=1, 
           cbar_kws={"shrink": .8}, square=True)
# ticks
yticks = [i.upper() for i in corr.index]
xticks = [i.upper() for i in corr.columns]
plt.yticks(plt.yticks()[0], labels=yticks, rotation=0)
plt.xticks(plt.xticks()[0], labels=xticks)
# title
title = 'CORRELATION MATRIX \n(1901-2018)'
plt.title(title,fontsize=18)
ax1.text(0,-1.4,'a',fontsize=30,weight="bold")

ax2 = fig.add_subplot(1,2,2)
biplot(df1,df1.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax2)
ax2.set_title('PCA-Biplot \n(1901-2018)', fontsize=20)
ax2.text(-1.2,1.3,'b',fontsize=30,weight="bold")

# ax2= fig.add_subplot(2,2,2)
# biplot(df_1901_1940,df_1901_1940.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax2)
# ax2.set_title('b) 1901-1940', fontsize=20)
# ax3= fig.add_subplot(2,2,3)
# biplot(df_1941_1980,df_1941_1980.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax3)
# ax3.set_title('c) 1941-1980', fontsize=20)
# ax4= fig.add_subplot(2,2,4)
# biplot(df_1981_2018,df_1981_2018.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax4)
# ax4.set_title('d) 1981-2018', fontsize=20)
plt.savefig("/home/cccr/roxy/athira/enso_paper/figure5_biplot_detrend2.png", bbox_inches='tight', pad_inches=0.5, dpi=300)
# Out:
# /tmp/ipykernel_54508/2671855438.py:9: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
# /tmp/ipykernel_54508/183440395.py:42: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle1 = plt.Circle((0, 0), 1.0, color='k',edgecolor='k',alpha=0.1)
# [0.2383438  0.17687908 0.13953208 0.1195742  0.09516774 0.0823464
#  0.07555828 0.04373098 0.02886743]

# %%
import numpy as np
import scipy as sc
from numpy import linalg as LA
def eof_wrap(matrix):
    ny            =         matrix.shape[0]
    mat           =         np.matrix(matrix)
    mean          =         mat.mean(0)
    std           =         mat.std(0)
    one           =         np.matrix(np.ones(ny,float))
    mean_matrix   =         one.T*mean
    std_matrix    =         one.T*std
    anomaly11     =         mat-mean_matrix
    anomaly22     =         anomaly11/std
    cov_matrix    =         anomaly22.T*anomaly22
    D,V           =         LA.eigh(cov_matrix)
    varex         =         D/np.sum(D)
    max_eig_ind   =         np.where(varex==np.max(varex))
    sec_eig_ind   =         np.where(varex==np.max(varex[varex<np.max(varex)]))
    third_eig_ind =         np.where(varex==np.max(varex[varex<varex[sec_eig_ind]]))
    fourth_eig_ind=         np.where(varex==np.max(varex[varex<varex[third_eig_ind]]))
    EOF1          =         V[:,max_eig_ind]
    EOF2          =         V[:,sec_eig_ind]
    EOF3          =         V[:,third_eig_ind]
    EOF4          =         V[:,fourth_eig_ind]
    PC1           =         anomaly11*np.squeeze(EOF1).T
    PC2           =         anomaly11*np.squeeze(EOF2).T
    PC3           =         anomaly11*np.squeeze(EOF3).T
    PC4           =         anomaly11*np.squeeze(EOF4).T
    reconstructed =         PC1*(np.squeeze(EOF1))+PC2*(np.squeeze(EOF2))+PC3*(np.squeeze(EOF3))
    return anomaly11,D,V,cov_matrix,EOF1,EOF2,EOF3,EOF4,varex,PC1,PC2,PC3,PC4,reconstructed

#%% testing significance of EOFs


def test_significance(D,ny):
    DD          =         np.sort(D)
    varex       =         DD/np.sum(DD)
    significant =         np.zeros(DD.size,float)  
    error =         np.zeros(DD.size,float)  
    k           =         0
    for i in range (DD.size):
         D_new  =         abs(DD-DD[i])
         error[i]  =         DD[i]*(2/ny)**0.5
         k      =         k+1
         if (sum(D_new>error[i])==DD.size-1):
             significant[i]=1
         else:
             significant[i]=0
        
    if significant[DD.size-1]==1:
        print("EOF1 is significant and pressenting variance %f" %varex[DD.size-1])
    else:
        print("EOF1 is not significant and pressenting variance %f" %varex[DD.size-1])

    if significant[DD.size-2]==1:
        print("EOF2 is significant and presenting variance %f" %varex[DD.size-2])
    else:
        print("EOF2 is not significant and pressenting variance %f" %varex[DD.size-2])
    
    if significant[DD.size-3]==1:
        print("EOF3 is significant and pressenting variance %f" %varex[DD.size-3])
    else:
        print("EOF3 is not significant and pressenting variance %f" %varex[DD.size-3])
    
    if significant[DD.size-4]==1:
        print("EOF4 is significant and pressenting variance %f" %varex[DD.size-4])
    else:
        print("EOF4 is not significant and pressenting variance %f" %varex[DD.size-4])

    
    
    return k,DD,significant,error,varex

# %%
anomaly11,D,V,cov_matrix,EOF1,EOF2,EOF3,EOF4,varex,PC1,PC2,PC3,PC4,reconstructed=eof_wrap(df1.values)

# %%
k,DD,significant,error,varex= test_significance(D,len(df1))
# Out:
# EOF1 is significant and pressenting variance 0.238344
# EOF2 is significant and presenting variance 0.176879
# EOF3 is significant and pressenting variance 0.139532
# EOF4 is significant and pressenting variance 0.119574
