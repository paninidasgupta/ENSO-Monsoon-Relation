# %%
from matplotlib import pyplot as plt
import numpy as np
import netCDF4 as nc
import xarray as xr
import datetime as dt
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from pandas import DataFrame

# %% [markdown]
# # Nino

# %%
# data1 = "/home/cccr/roxy/athira/ninosst.txt"
# f = open("ninosst.txt", "r")

matrix1=np.loadtxt("/home/cccr/roxy/athira/biplot_monsoon/ninosst.txt")
year=matrix1[:,0]
data=matrix1[:,1:]
ind1= np.where((year==1901))[0][0]
ind2= np.where((year==2018))[0][0]
year1=matrix1[ind1:ind2+1,0]
data1=matrix1[ind1:ind2+1,1:]
data1_df=pd.DataFrame(data1,index=year1)
aa=data1_df.iloc[:,[5,6,7,8]].values.ravel()
a=pd.Series(aa,pd.date_range('1/06/1901', periods=len(aa), freq='T'))
bb=a.resample('4T').mean().values
index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')
b=pd.Series(bb,index = index1)


# b.plot(color='red' , label ='ninosst')
# plt.legend(loc="best")
# std = np.std(b)
nino_df=pd.DataFrame(b, index=index1, columns=[' N3.4 '])
# nino_df
# Out:
# /home/cccr/roxy/.conda/envs/saranya/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from ipykernel import kernelapp as app

# %%
# %store nino_df
# Out:
# Stored 'nino_df' (DataFrame)

# %% [markdown]
# # AMO

# %%
matrix1 = np.loadtxt("/home/cccr/roxy/athira/biplot_monsoon/amo.txt")



year=matrix1[:,0]
data=matrix1[:,1:]
ind1= np.where((year==1901))[0][0]
ind2= np.where((year==2018))[0][0]
year1=matrix1[ind1:ind2+1,0]
data1=matrix1[ind1:ind2+1,1:]
data1_df=pd.DataFrame(data1,index=year1)
aa=data1_df.iloc[:,[5,6,7,8]].values.ravel()
a=pd.Series(aa,pd.date_range('1/06/1901', periods=len(aa), freq='T'))
bb=a.resample('4T').mean().values
index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')
b=pd.Series(bb,index = index1)


# b.plot(color='red' , label ='AMO')
# plt.legend(loc="best")
# std = np.std(b)

amo_df=pd.DataFrame(b, index=index1, columns=['AMO'])
# amo_df

#plt.savefig('Desktop/DATA' +'kik.png',  bbox_inches='tight', pad_inches=0.5, dpi=150)



# year.shape
# Out:
# /home/cccr/roxy/.conda/envs/saranya/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from ipykernel import kernelapp as app

# %% [markdown]
# # PDO

# %%
matrix2 = np.loadtxt("/home/cccr/roxy/athira/biplot_monsoon/pdo.txt")



year=matrix2[:,0]
data=matrix2[:,1:]
ind1= np.where((year==1901))[0][0]
ind2= np.where((year==2018))[0][0]
year1=matrix2[ind1:ind2+1,0]
data1=matrix2[ind1:ind2+1,1:]
data1_df=pd.DataFrame(data1,index=year1)
aa=data1_df.iloc[:,[5,6,7,8]].values.ravel()
a=pd.Series(aa,pd.date_range('1/06/1901', periods=len(aa), freq='T'))
bb=a.resample('4T').mean().values
index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')
b=pd.Series(bb,index = index1)


# b.plot(color='blue' , label ='PDO')
# plt.legend(loc="best")
# std = np.std(b)
pdo_df=pd.DataFrame(b, index=index1, columns=['PDO'])
# pdo_df
# Out:
# /home/cccr/roxy/.conda/envs/saranya/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from ipykernel import kernelapp as app

# %% [markdown]
# # NAO

# %%
matrix3 = np.loadtxt("/home/cccr/roxy/athira/biplot_monsoon/nao.txt")



year=matrix3[:,0]
data=matrix3[:,1:]
ind1= np.where((year==1901))[0][0]
ind2= np.where((year==2018))[0][0]
year1=matrix3[ind1:ind2+1,0]
data1=matrix3[ind1:ind2+1,1:]
data1_df=pd.DataFrame(data1,index=year1)
aa=data1_df.iloc[:,[5,6,7,8]].values.ravel()
a=pd.Series(aa,pd.date_range('1/06/1901', periods=len(aa), freq='T'))
bb=a.resample('4T').mean().values
index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')
b=pd.Series(bb,index = index1)


# b.plot(color='green' , label ='NAO')
# plt.legend(loc="best")
# std = np.std(b)

nao_df=pd.DataFrame(b, index=index1, columns=['NAO'])
# nao_df
# Out:
# /home/cccr/roxy/.conda/envs/saranya/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from ipykernel import kernelapp as app

# %% [markdown]
# # QBO_1948-2018

# %%
matrix4 = np.loadtxt("/home/cccr/roxy/athira/biplot_monsoon/qbo.txt")



year=matrix4[:,0]
data=matrix4[:,1:]
ind1= np.where((year==1901))[0][0]
ind2= np.where((year==2018))[0][0]
year1=matrix4[ind1:ind2+1,0]
data1=matrix4[ind1:ind2+1,1:]
data1_df=pd.DataFrame(data1,index=year1)
aa=data1_df.iloc[:,[5,6,7,8]].values.ravel()
a=pd.Series(aa,pd.date_range('1/06/1901', periods=len(aa), freq='T'))
bb=a.resample('4T').mean().values
index1 = pd.date_range(start=pd.datetime(1901,6,1),periods=len(bb),freq='AS-JUL')
b=pd.Series(bb,index = index1)


# b.plot(color='indigo' , label ='QBO')
# plt.legend(loc="best")
# std = np.std(b)

qbo_df=pd.DataFrame(b, index=index1, columns=['QBO'])
qbo_df_2=qbo_df.loc['1948':'2018']
std=qbo_df_2['QBO'].std
# qbo_df_std['qbo']/std
# std=pd.Series(std)
# std.to_frame()
# Out:
# /home/cccr/roxy/.conda/envs/saranya/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from ipykernel import kernelapp as app

# %% [markdown]
# # PC1 & PC2

# %%
data5 = xr.open_dataset("/home/cccr/roxy/athira/pc.yearmean.nc")
pcs=data5.pcs.values
pcs=pcs[:-1]
# time=data5.time.values
pcs_df = pd.DataFrame(pcs, index = index1, columns=['IPC1','IPC2','pc3'])
pcs_df=pcs_df.drop(['pc3'], axis=1)

# %% [markdown]
# # South_box

# %%
data6 = xr.open_dataset("/home/cccr/roxy/athira/southbox_imd_V2.nc")
rf_s=data6.rf.values
time_s=data6.time.values
south_df = pd.DataFrame(rf_s, index = index1, columns=['S-box'])
# south_df

# %% [markdown]
# # Central_box

# %%
data7 = xr.open_dataset("/home/cccr/roxy/athira/centralbox_imd_V2.nc")
rf_c=data7.rf.values
time_c=data7.time.values
central_df = pd.DataFrame(rf_c, index = index1, columns=['C-box'])
# central_df

# %% [markdown]
# # North_box

# %%
data8 = xr.open_dataset("/home/cccr/roxy/athira/northbox_imd_V2.nc")
rf_n=data8.rf.values
time_n=data8.time.values
north_df = pd.DataFrame(rf_n, index = index1, columns=['N-box'])
# north_df

# %% [markdown]
# # ANI

# %%
ds = xr.open_dataset('/home/cccr/roxy/athira/biplot_monsoon/pc.jjas.atlantic.nino.nc')
ds1=ds.sel(time=slice('1901','2018'))
ds1
pcs=ds1.pcs.values
# # time=data5.time.values
ani_df = pd.DataFrame(pcs, index = index1, columns=['ANIPC1','ANIPC2','anipc3'])
ani_df=ani_df.drop(['ANIPC2','anipc3'], axis=1)

# %% [markdown]
# # DMI

# %%
data9 = xr.open_dataset('/home/cccr/roxy/athira/biplot_monsoon/ihadisst1_dmi_mod.jjas.yearmean.1901_2018.nc',decode_times=False)
index2 = pd.date_range(start=pd.datetime(1901,7,1),periods=len(data9['diff']),freq='AS-JUL')
dmi_df = pd.DataFrame(data9['diff'], index = index2, columns=['DMI'])
# dmi_df
# Out:
# /home/cccr/roxy/.conda/envs/saranya/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.

# %% [markdown]
# # QBO_1901-2018

# %%
data10 = xr.open_dataset('/home/cccr/roxy/athira/biplot_monsoon/iqbo_mode.jjas.yearmean.1901_2018.nc',decode_times=False )
index3 = pd.date_range(start=pd.datetime(1901,7,1),periods=len(data10['QBO50']),freq='AS-JUL')
qbo_new_df = pd.DataFrame(data10['QBO50'], index = index3, columns=['QBO'])
qbo_new_df
# data10
qbo_new_df1=qbo_new_df.loc['1901':'1947']
# Out:
# /home/cccr/roxy/.conda/envs/saranya/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.

# %%
# qbo_modified=pd.concat([qbo_new_df1,qbo_df_2], axis=0)
qbo_modified=pd.concat([qbo_new_df1/qbo_new_df1.std(),qbo_df_2/qbo_df_2.std()], axis=0)

qbo_modified.plot()

# %%
# !cdo settaxis,1870-01-01,00:00:00,1months ihadisst1_dmi.nc ihadisst1_dmi_mod.nc
# !cdo selmon,6/9 ihadisst1_dmi_mod.nc ihadisst1_dmi_mod.jjas.nc
# !cdo yearmean ihadisst1_dmi_mod.jjas.nc ihadisst1_dmi_mod.jjas.yearmean.nc
# !cdo selyear,1901/2018 ihadisst1_dmi_mod.jjas.yearmean.nc ihadisst1_dmi_mod.jjas.yearmean.1901_2018.nc 
# !rm ihadisst1_dmi_mod*.nc
# !cdo sinfo iqbo_50.nc
# !cdo settaxis,1501-01-01,00:00:00,1months iqbo_50.nc iqbo_mode.nc
# !cdo selmon,6/9 iqbo_mode.nc iqbo_mode.nc.jjas.nc
# !cdo yearmean iqbo_mode.nc.jjas.nc iqbo_mode.nc.jjas.yearmean.nc
# !cdo selyear,1901/2018 iqbo_mode.nc.jjas.yearmean.nc iqbo_mode.nc.jjas.yearmean.1901_2018.nc

# %%
import seaborn as sns

# %%
df_1901_1940 = pd.concat([-1*nino_df.loc['1901':'1940'],pdo_df.loc['1901':'1940'],nao_df.loc['1901':'1940'],qbo_modified.loc['1901':'1940'],amo_df.loc['1901':'1940'],pcs_df.loc['1901':'1940'],south_df.loc['1901':'1940'],central_df.loc['1901':'1940'],north_df.loc['1901':'1940'],ani_df.loc['1901':'1940'],dmi_df.loc['1901':'1940']], axis=1)
df_1941_1980 =pd.concat([-1*nino_df.loc['1941':'1980'],pdo_df.loc['1941':'1980'],nao_df.loc['1941':'1980'],qbo_modified.loc['1941':'1980'],amo_df.loc['1941':'1980'],pcs_df.loc['1941':'1980'],south_df.loc['1941':'1980'],central_df.loc['1941':'1980'],north_df.loc['1941':'1980'],ani_df.loc['1941':'1980'],dmi_df.loc['1941':'1980']], axis=1)
df_1981_2018 =pd.concat([-1*nino_df.loc['1981':'2018'],pdo_df.loc['1981':'2018'],nao_df.loc['1981':'2018'],qbo_modified.loc['1981':'2018'],amo_df.loc['1981':'2018'],pcs_df.loc['1981':'2018'],south_df.loc['1981':'2018'],central_df.loc['1981':'2018'],north_df.loc['1981':'2018'],ani_df.loc['1981':'2018'],dmi_df.loc['1981':'2018']], axis=1)
df = pd.concat([-1*nino_df,pdo_df,nao_df,qbo_modified,amo_df,pcs_df,south_df,central_df,north_df,ani_df,dmi_df], axis=1)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm')

# %% [markdown]
# # Figure 2- Biplot

# %%
def biplot(X,header,target,ax,scale = True,labels=None):
    import numpy as np
    from sklearn.decomposition import PCA
    from sklearn.preprocessing import StandardScaler
    import matplotlib.pyplot as plt

    plt.rcParams.update({'font.size': 20, 'font.family': 'serif'})

    if scale:
        scaler = StandardScaler()
        scaler.fit(X)
        X = scaler.transform(X) 

    pca = PCA()
    x_new = pca.fit_transform(X)  
    score = x_new[:,0:2]
    coeff = np.transpose(pca.components_[0:2, :])  
    print(pca.explained_variance_ratio_)
    xs = score[:,0]
    ys = score[:,1]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())

#     scatter = plt.scatter(xs * scalex,ys * scaley, c = target)
#     ll = np.unique(target)
#     handles = [plt.Line2D([],[],marker="o", ls="", 
#                       color=scatter.cmap(scatter.norm(yi))) for yi in ll]
#     plt.legend(handles, ll)

    for i,val in enumerate(header):
        ax.annotate("", xy=(coeff[i,0], coeff[i,1]), xytext=(0, 0),color = 'k',alpha = 0.5,arrowprops=dict(arrowstyle="->"))
        if labels is None:
            ax.text(coeff[i,0]* 1.18, coeff[i,1] * 1.18, val, color = 'k', ha = 'center', va = 'center')
        else:
            ax.text(coeff[i,0]* 1.18, coeff[i,1] * 1.18, labels[i], color = 'k', ha = 'center', va = 'center')

    ax.set_xlim(-1.2,1.2)
    ax.set_ylim(-1.2,1.2)
    ax.set_xlabel(" PC{}".format(1)+" ("+str(np.around(pca.explained_variance_ratio_[0]*100,2))+"%)")
    ax.set_ylabel(" PC{}".format(2)+" ("+str(np.around(pca.explained_variance_ratio_[1]*100,2))+"%)")
    ax.grid()
    circle1 = plt.Circle((0, 0), 1.0, color='k',edgecolor='k',alpha=0.1)
    ax.add_artist(circle1)

# %%
df1 =df.dropna()

# %%
fig= plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(2,2,1)
biplot(df,df.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax1)
ax1.set_title(r'$\bf{{{a)}}}$ 1901-2018', fontsize=30)
ax2= fig.add_subplot(2,2,2)
biplot(df_1901_1940,df_1901_1940.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax2)
ax2.set_title(r'$\bf{{{b)}}}$ 1901-1940', fontsize=30)
ax3= fig.add_subplot(2,2,3)
biplot(df_1941_1980,df_1941_1980.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax3)
ax3.set_title(r'$\bf{{{c)}}}$ 1941-1980', fontsize=30)
ax4= fig.add_subplot(2,2,4)
biplot(df_1981_2018,df_1981_2018.columns,target=['k','k','k','k','k','k','k','k','k','k','k'],ax=ax4)
ax4.set_title(r'$\bf{{{d)}}}$ 1981-2018', fontsize=30)
plt.savefig("/home/cccr/roxy/athira/enso_paper/figure5_biplot.png", bbox_inches='tight', pad_inches=0.5, dpi=300)
# Out:
# [0.2994958  0.15035978 0.11667452 0.10500138 0.0829205  0.06380418
#  0.05890463 0.0526544  0.03098492 0.01908192 0.01562965 0.00448832]
# [0.30720534 0.17176811 0.1371361  0.11287375 0.0743545  0.06161352
#  0.05261555 0.03647031 0.02335724 0.01249393 0.00772537 0.00238628]
# [0.35622638 0.13518192 0.12551343 0.09903332 0.08262235 0.0587052
#  0.04946677 0.0415216  0.02140285 0.01840599 0.01070322 0.00121697]
# [0.28343927 0.17125545 0.14421098 0.11736104 0.08724592 0.05933473
#  0.05502022 0.03333079 0.02851283 0.01111068 0.00670981 0.00246828]
# /home/cccr/roxy/.conda/envs/saranya/lib/python3.7/site-packages/ipykernel_launcher.py:42: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
# /home/cccr/roxy/.conda/envs/saranya/lib/python3.7/site-packages/ipykernel_launcher.py:42: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
# /home/cccr/roxy/.conda/envs/saranya/lib/python3.7/site-packages/ipykernel_launcher.py:42: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
# /home/cccr/roxy/.conda/envs/saranya/lib/python3.7/site-packages/ipykernel_launcher.py:42: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
